# %%
# 2023-05-05 Выгрузка корректировочной таблицы

# %%
#+++ версия 2025.04.14 tg: Цифриум, команда 2 Машинисты, @codeup1054, @Kimutogo,@Eques8, @serin_1995, @saturnian1, @tyuop077
from importlib import reload
import sys, os 

current_dir = os.getcwd()

for i in ['utils','datetime','glob']:
    if i in sys.modules: del  sys.modules[i] 
    exec (f'from {i} import *')  
    
    
tm()

i = 0
for k in dir(ps):
    if ('_' not in k) and isinstance(getattr(ps, k), str) :
        print (f"{getattr(ps, k)}{k:^9}{ps._} ", end="")
        if (i := i+1)%8 == 0 : print("")

dfr = dfr if 'dfr' in vars() else {}
tm('\n>>>')
# Out:
#  *** Start at: 16:21:28 2025-04-15  ************************************************************
#   BBLUE     BGRAY    BGREEN    BLBLUE    BLCYAN    BLGRAY    BLGREEN   BLILAC
#  BLLBLUE  BLMAGENTA   BLRED     BLUE       BLY    BLYELLOW  BMAGENTA    BOLD
#  BORANGE    BRED       BY      BYELLOW    CYAN    DARKCYAN      E        END
#    ERR      GRAY      GREEN     LBLUE     LGRAY    LGREEN   LMAGENTA    LRED
#  MAGENTA   ORANGE    PURPLE      RED        T       TOTAL   UNDERLINE     Y
#  YELLOW      err      0:00:00.000  ₀⡄₀₀⡄₀₀.₀₀₀
# >>>
# datetime.datetime(2025, 4, 15, 16, 21, 28, 601417)

# %% [markdown]
# ### 01. Files

# %%
import glob
glob.glob(r'conspects/*')
# Out:
# ['conspects\\conspect-00.txt',
#  'conspects\\conspectmodel_claude-3.7-sonnet-reasoning-gemma3-12B.Q8_0.gguf.txt',
#  'conspects\\conspectmodel_meta-llama-3-8b-instruct.Q4_K_M.gguf.txt',
#  'conspects\\conspectmodel_mistral-7b-instruct-v0.1.Q3_K_L.gguf.txt',
#  'conspects\\conspectmodel_mistral-7b-instruct-v0.1.Q8_0.gguf.txt',
#  'conspects\\conspectmodel_mistral-7b-instruct-v0.1.Q8_0.gguf_1.txt',
#  'conspects\\conspect_API_claude-3-7-sonnet-20250219.txt',
#  'conspects\\conspect_gpt-3.5-turbo.txt',
#  'conspects\\conspect_gpt-4.txt',
#  'conspects\\conspect_IlyaGusev_rut5_base_sum_gazeta.txt',
#  'conspects\\conspect_mbart.txt',
#  'conspects\\IlyaGusev_rut5_base_sum_gazeta.txt',
#  'conspects\\_API_claude-3-7-sonnet-20250219.txt']

# %% [markdown]
# ### 01.01 simple pptx

# %%
from pptx import Presentation
from pptx.util import Inches, Pt
import re

tm()

def parse_text_file(filename):
    with open(filename, encoding='utf-8') as f:
        lines = f.readlines()
    # Извлечение заголовка и подзаголовка
    title = lines[0].strip()
    subtitle = lines[1].strip()
    content = ''.join(lines[2:])
    # sections = re.split(r'# |\n', content)

    pattern = r'#\s*(.+?)\s*(?=\n|$)(.*?)(?=(#\s|$))'
    
    
    # Извлечение заголовков и содержания
    sections = re.findall(pattern, content, re.DOTALL)
    # print (sections)
    
        
    blocks = {}

    for section in sections:
        if len(section) == 3:
            header,body, _ = section
            blocks[header.strip()] = body.strip()
        else:
            blocks[header.strip()] += '\n' + section.strip()

    return title, subtitle, blocks

def create_pptx(title, subtitle, blocks, template_file, output_file):
    prs = Presentation(template_file)

    # Добавление титульного слайда
    title_slide_layout = prs.slide_layouts[0]  # Макет титульного слайда
    slide = prs.slides.add_slide(title_slide_layout)
    slide.shapes.title.text = title
    slide.placeholders[1].text = subtitle

    for section, content in blocks.items():
        slide_layout = prs.slide_layouts[1]  # Макет слайда с заголовком и содержимым
        slide = prs.slides.add_slide(slide_layout)
        slide.shapes.title.text = section

        content_placeholder = slide.placeholders[1]
        content_placeholder.text = content

    prs.save(output_file)
    print(f"✅ Презентация сохранена в: {output_file}")


STRUCTURIZED_FILE = r'conspects\\conspect_API_claude-3-7-sonnet-20250219.md'
TEMPLATE_FILE = 'themes.pptx'

output_file = rf'pptx/{STRUCTURIZED_FILE[10:-4]}.pptx'

if __name__ == "__main__":
    title, subtitle, blocks = parse_text_file(STRUCTURIZED_FILE)
    create_pptx(title, subtitle, blocks, TEMPLATE_FILE, output_file)
tm('>>>')
# Out:
#  *** Start at: 16:23:42 2025-04-15  ************************************************************
# # Общественное движение в России во второй четверти XIX века  {'# План занятия': '1. Основные направления общественного движения\n2. Консервативное направление \n3. Либеральное направление (западники и славянофилы)\n4. Революционное (радикальное) направление\n5. Студенческие кружки 1820-30-х годов\n\n#', 'Основные концепции': '##', 'Три направления общественного движения': '- **Консервативное** — сохранение самодержавия и существующего порядка\n- **Либеральное** — реформирование государства, отмена крепостного права\n- **Радикальное** — революционные преобразования общества\n\n##', 'Теория официальной народности (С.С. Уваров)': 'Базировалась на трех принципах:\n- **Самодержавие** — основа жизни русского общества\n- **Православие** — ориентация на общее благо и справедливость\n- **Народность** — единство народа, сплоченного вокруг царя\n\n##', 'Либеральные течения': '- **Славянофильство** — религиозно-философское течение, выступавшее за самобытный путь развития России\n- **Западничество** — движение за европейский путь развития России\n\n##', 'Революционное направление': '- Продолжение идей декабристов\n- Влияние французского утопического социализма\n- Идея революции как единственного пути преобразования государства\n\n#', 'Ключевые персоны': '##', 'Консерваторы': '- **Сергей Семенович Уваров** — идеолог консерватизма, автор теории официальной народности\n- **Николай Герасимович Устрялов** — сторонник консервативных идей\n- **Михаил Петрович Погодин** — историк, консерватор\n- **Фаддей Венедиктович Булгарин** — писатель, журналист\n- **Николай Иванович Греч** — писатель, редактор\n- **Михаил Николаевич Загоскин** — писатель\n\n##', 'Славянофилы': '- **Алексей и Константин Аксаковы** — теоретики славянофильства\n- **Иван и Петр Киреевские** — идеологи славянофильства\n- **Юрий Федорович Самарин** — общественный деятель\n- **Александр Иванович Кошелев** — публицист\n- **Александр Степанович Хомяков** — основоположник идей славянофилов\n\n##', 'Западники': '- **Тимофей Николаевич Грановский** — историк, лидер западников\n- **Сергей Михайлович Соловьев** — историк\n- **Константин Дмитриевич Кавелин** — историк, юрист\n- **Павел Васильевич Анненков** — литературный критик\n- **Василий Петрович Боткин** — литературный критик\n- **Иван Сергеевич Тургенев** — писатель\n\n##', 'Влиявшие на оба либеральных направления': '- **Петр Яковлевич Чаадаев** — философ, публицист, автор "Философических писем"\n\n##', 'Радикалы': '- **Александр Иванович Герцен** — создатель теории русского социализма\n- **Николай Платонович Огарев** — поэт, публицист\n- **Михаил Васильевич Петрашевский** — руководитель революционного кружка\n- **Федор Михайлович Достоевский** — писатель, член кружка Петрашевского\n- **Михаил Евграфович Салтыков-Щедрин** — писатель, член кружка Петрашевского\n- **Николай Алексеевич Спешнев** — революционер, член кружка Петрашевского\n\n#', 'Сравнение концепций': '| Направление | Отношение к самодержавию | Отношение к крепостному праву | Путь развития России | Методы изменений |\n|-------------|--------------------------|-------------------------------|----------------------|------------------|\n| Консерваторы | Поддержка, основа государства | Сохранение | Самобытный, без заимствований | Не нужны, вредны |\n| Славянофилы | Сохранение, но с совещательным органом | Отмена | Самобытный, возврат к допетровским традициям | Реформы сверху |\n| Западники | Замена на конституционную монархию | Отмена | Европейский, по пути Петра I | Реформы сверху |\n| Радикалы | Свержение | Отмена | Социалистический, революционный | Революция |\n\n#', 'Даты ключевых событий': '- **1830-1850-е гг.** — оформление славянофильства как течения\n- **1836 г.** — публикация "Философического письма" П.Я. Чаадаева в журнале "Телескоп"\n- **1826-1827 гг.** — деятельность кружка братьев Критских\n- **1831-1834 гг.** — действие кружка А.И. Герцена и Н.П. Огарева\n- **1845-1849 гг.** — существование кружка М.В. Петрашевского\n- **1849 г.** — аресты членов кружка Петрашев ...
# ✅ Презентация сохранена в: pptx/\conspect_API_claude-3-7-sonnet-2025021.pptx
#   0:00:00.095  ₀⡄₀₀⡄₀₀.₀₉₅ >>>
# datetime.datetime(2025, 4, 15, 16, 23, 42, 360053)

# %% [markdown]
# ### 01.03 conspect to pptx with table

# %%
tm()
from pptx import Presentation
from pptx.util import Inches, Pt
from pptx.enum.shapes import MSO_AUTO_SHAPE_TYPE
from pptx.dml.color import RGBColor
from pptx.oxml.xmlchemy import OxmlElement
from pptx.oxml.ns import qn

import markdown
from bs4 import BeautifulSoup

def set_cell_font_size(cell, font_size=Pt(12)):
    # Проверяем, существует ли текстовый фрейм
    if cell.text_frame is None:
        # Создаем текстовый фрейм, если его нет
        cell.text_frame = cell._element.get_or_add_text()

    # Применяем размер шрифта ко всем параграфам в ячейке
    for paragraph in cell.text_frame.paragraphs:
        for run in paragraph.runs:
            run.font.size = font_size

def set_run_style(run, bold=False, italic=False):
    run.font.bold = bold
    run.font.italic = italic
    run.font.size = Pt(15)  # Стандартный размер шрифта для этого стиля
    run.font.name = 'Arial'
    run.font.color.rgb = RGBColor(0, 0, 0)  # Черный цвет шрифта

def parse_html_to_slide(title, html_content, slide, font_size=Pt(12)):
    textbox = slide.placeholders[1]
    textbox.text = ""  # Очистим, если там уже есть текст
    tf = textbox.text_frame

    soup = BeautifulSoup(html_content, "html.parser")

    for element in soup.contents:
        if element.name == "p":
            p = tf.add_paragraph()
            for part in element.descendants:
                if part.name is None:
                    run = p.add_run()
                    run.text = part
                elif part.name == "strong":
                    run = p.add_run()
                    run.text = part.text
                    set_run_style(run, bold=True)
                elif part.name == "em":
                    run = p.add_run()
                    run.text = part.text
                    set_run_style(run, italic=True)
        elif element.name == "ul":
            for li in element.find_all("li"):
                p = tf.add_paragraph()
                p.text = f"• {li.text}"
                p.level = 0
        elif element.name == "table":
            rows = element.find_all("tr")
            cols_count = len(rows[0].find_all(["th", "td"]))
            table_shape = slide.shapes.add_table(len(rows), cols_count, Inches(1), Inches(2.5), Inches(10), Inches(0.7 * len(rows)))
            table = table_shape.table
            for r, row in enumerate(rows):
                for c, cell in enumerate(row.find_all(["td", "th"])):
                    table.cell(r, c).text = cell.text
                    set_cell_font_size(table.cell(r, c), font_size)

# Пример Markdown-текста
STRUCTURIZED_FILE = r'conspects\\conspect_API_claude-3-7-sonnet-20250219.md'
TEMPLATE_FILE = 'themes.pptx'

with open(CONSPECT_FILE, encoding='utf-8') as f:
    markdown_text = f.read()

# Конвертируем Markdown в HTML
html = markdown.markdown(markdown_text, extensions=['tables'])
soup = BeautifulSoup(html, "html.parser")

# Загрузка шаблона презентации
template_path = 'themes.pptx'  # Укажите путь к вашему шаблону
prs = Presentation(template_path)

# Выбор макета для титульного слайда и слайдов с текстом
title_slide_layout = prs.slide_layouts[0]  # Для титульного слайда
bullet_slide_layout = prs.slide_layouts[1]  # Для остальных слайдов

current_title = None
current_html_content = []

def add_title_slide(title):
    slide = prs.slides.add_slide(title_slide_layout)
    slide.shapes.title.text = title

def add_slide(title, html_content, font_size=Pt(12)):
    slide = prs.slides.add_slide(bullet_slide_layout)
    slide.shapes.title.text = title
    parse_html_to_slide(title, html_content, slide, font_size)

# Обработка заголовков и контента
first_slide_added = False
font_size = Pt(10)  # Пример изменения размера шрифта для всей презентации

for element in soup.contents:
    if element.name == 'h1' and not first_slide_added:
        # Добавляем титульный слайд для первого заголовка
        add_title_slide(element.text)
        first_slide_added = True
    elif element.name == 'h2':
        # Добавляем новый слайд для заголовков H2
        if current_title:
            add_slide(current_title, "".join(str(e) for e in current_html_content), font_size)
            current_html_content = []
        current_title = element.text
    else:
        current_html_content.append(element)

# Добавляем последний слайд, если остался незавершённый контент
if current_title:
    add_slide(current_title, "".join(str(e) for e in current_html_content), font_size)

# Сохранение презентации
prs.save(f"{STRUCTURIZED_FILE}.pptx")
tm('>>>')
# Out:
#  *** Start at: 16:25:28 2025-04-15  ************************************************************
#   0:00:00.274  ₀⡄₀₀⡄₀₀.₂₇₄ >>>
# datetime.datetime(2025, 4, 15, 16, 25, 28, 819753)
